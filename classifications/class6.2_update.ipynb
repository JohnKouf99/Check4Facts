# %%
import sys
sys.path.append('../scripts')  
from models import *
from df_handling import * 
from text_embedding import *
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/politifacts_emb.csv')
df = unravel_df(df, ['text_embedding'])

# %%
df.verdict.value_counts()
# Out:
# 0    5625
# 2    3597
# 4    3432
# 3    3332
# 5    2703
# 1    2463
# Name: verdict, dtype: int64

# %%
#same as class6 file but drop labels instead of merging
df = df[(df.verdict==0) | (df.verdict==1) | (df.verdict==2)]

# %%
df.verdict.value_counts()
# Out:
# 0    5625
# 2    3597
# 1    2463
# Name: verdict, dtype: int64

# %%
arr = [df.iloc[i,2] for i in range(len(df))]


X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,0]).astype('int'), test_size=0.2, random_state=42)

# %%
NaiveBayes(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.537
#
# Model Recall: 0.537
#
# Model Precision: 0.551
#
# Model F1-Score: 0.542
#
# Cross validation score: [0.508 0.551 0.523 0.526 0.541 0.55  0.52  0.545 0.54  0.558]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.62      0.65      1096
#            1       0.39      0.50      0.44       494
#            2       0.46      0.44      0.45       747
#
#     accuracy                           0.54      2337
#    macro avg       0.51      0.52      0.51      2337
# weighted avg       0.55      0.54      0.54      2337

# %%
LogisticReg(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.567
#
# Model Recall: 0.567
#
# Model Precision: 0.552
#
# Model F1-Score: 0.551
#
# Cross validation score: [0.552 0.579 0.56  0.576 0.58  0.574 0.575 0.583 0.558 0.573]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.75      0.68      1096
#            1       0.47      0.27      0.34       494
#            2       0.49      0.49      0.49       747
#
#     accuracy                           0.57      2337
#    macro avg       0.53      0.50      0.51      2337
# weighted avg       0.55      0.57      0.55      2337

# %%
SVM(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.565
#
# Model Recall: 0.565
#
# Model Precision: 0.553
#
# Model F1-Score: 0.545
#
# Cross validation score: [0.552 0.567 0.556 0.567 0.566 0.584 0.559 0.581 0.56  0.574]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.76      0.68      1096
#            1       0.50      0.23      0.31       494
#            2       0.48      0.50      0.49       747
#
#     accuracy                           0.56      2337
#    macro avg       0.54      0.50      0.50      2337
# weighted avg       0.55      0.56      0.54      2337

# %%
KNeigh(X_train, X_test, y_train, y_test)
# Out:
#   File "c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Model Accuracy: 0.507
#
# Model Recall: 0.507
#
# Model Precision: 0.493
#
# Model F1-Score: 0.497
#
# Cross validation score: [0.524 0.548 0.526 0.525 0.544 0.539 0.539 0.506 0.533 0.558]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.70      0.65      1096
#            1       0.34      0.33      0.34       494
#            2       0.43      0.34      0.38       747
#
#     accuracy                           0.51      2337
#    macro avg       0.46      0.46      0.45      2337
# weighted avg       0.49      0.51      0.50      2337

# %%
DecisionTree(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.427
#
# Model Recall: 0.427
#
# Model Precision: 0.43
#
# Model F1-Score: 0.428
#
# Cross validation score: [0.434 0.443 0.436 0.472 0.468 0.428 0.41  0.45  0.428 0.456]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.55      0.56      1096
#            1       0.24      0.27      0.25       494
#            2       0.36      0.35      0.35       747
#
#     accuracy                           0.43      2337
#    macro avg       0.39      0.39      0.39      2337
# weighted avg       0.43      0.43      0.43      2337

# %%
RandomForest(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.525
#
# Model Recall: 0.525
#
# Model Precision: 0.514
#
# Model F1-Score: 0.47
#
# Cross validation score: [0.522 0.529 0.529 0.54  0.535 0.543 0.512 0.536 0.548 0.548]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.85      0.66      1096
#            1       0.52      0.10      0.17       494
#            2       0.46      0.33      0.38       747
#
#     accuracy                           0.53      2337
#    macro avg       0.51      0.43      0.41      2337
# weighted avg       0.51      0.53      0.47      2337

# %%
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.528
#
# Model Recall: 0.528
#
# Model Precision: 0.528
#
# Model F1-Score: 0.527
#
# Cross validation score: [0.522 0.523 0.536 0.563 0.524 0.529 0.528 0.529 0.515 0.542]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64      1096
#            1       0.37      0.40      0.39       494
#            2       0.47      0.44      0.46       747
#
#     accuracy                           0.53      2337
#    macro avg       0.49      0.49      0.49      2337
# weighted avg       0.53      0.53      0.53      2337
