# %%
import sys
sys.path.append('../scripts')  
from models import *
from df_handling import *
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#train me to olo to elliniko dataset me train/test/split
df1 = pd.read_csv('../data/greek_web_scraping_emb.csv')
df1 = unravel_df(df1, ['text_embedding'])


df2 = pd.read_csv('../data/test1.csv')
df2.rename(columns={'predict_label': 'label'}, inplace=True)
df2 = unravel_df(df2, ['text_embedding'])

df = pd.concat([df1,df2], ignore_index=True)

# %%
arr = [df.iloc[i,2] for i in range(len(df))]


X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)

# %%
NaiveBayes(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
LogisticReg(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
SVM(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
KNeigh(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
RandomForest(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
DecisionTree(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.615
#
# Model Recall: 0.615
#
# Model Precision: 0.597
#
# Model F1-Score: 0.603
#
# Cross validation score: [0.593 0.667 0.722 0.815 0.722 0.778 0.815 0.704 0.667 0.774]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.61      0.63        74
#            1       0.58      0.69      0.63        55
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.61       135
#    macro avg       0.41      0.43      0.42       135
# weighted avg       0.60      0.61      0.60       135

# %%
MLP(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
train1 = pd.read_csv('../data/greek_web_scraping_emb.csv')
train2 = pd.read_csv('../data/cyprus_factcheck_emb.csv')
train3 = pd.read_csv('../data/fullfacts_emb.csv')
train4 = pd.read_csv('../data/snopes2_emb.csv', nrows=1000)
train5 = pd.read_csv('../data/reuters_emb.csv')
train6 = pd.read_csv('../data/test1.csv')

train1 = unravel_df(train1, ['text_embedding'])
train2 = unravel_df(train2, ['text_embedding'])
train3 = unravel_df(train3, ['text_embedding'])
train4 = unravel_df(train4, ['text_embedding'])
train5 = unravel_df(train5, ['text_embedding'])
train6 = unravel_df(train6, ['text_embedding'])


train6.rename(columns={'predict_label': 'label'}, inplace=True)

train3.dropna(inplace=True)
train3.reset_index(drop=True, inplace=True)
train4.dropna(inplace=True)
train4.reset_index(drop=True, inplace=True)

# %%
#factcheckgreek+greekhoaxes+cyprus+postgres
df = pd.concat([train1,train2,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.851
#
# Model Recall: 0.851
#
# Model Precision: 0.858
#
# Model F1-Score: 0.854
#
# Cross validation score: [0.892 0.815 0.859 0.859 0.875 0.812 0.812 0.859 0.875 0.844]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        82
#            1       0.84      0.88      0.86        77
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.85       161
#    macro avg       0.58      0.57      0.58       161
# weighted avg       0.86      0.85      0.85       161

# %%
#factcheckgreek+greekhoaxes+cyprus+postgres+snopes
df = pd.concat([train1,train2,train4,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.741
#
# Model Recall: 0.741
#
# Model Precision: 0.733
#
# Model F1-Score: 0.737
#
# Cross validation score: [0.672 0.752 0.696 0.704 0.656 0.728 0.696 0.64  0.712 0.726]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78       181
#            1       0.69      0.68      0.69       129
#            2       0.00      0.00      0.00         3
#
#     accuracy                           0.74       313
#    macro avg       0.49      0.49      0.49       313
# weighted avg       0.73      0.74      0.74       313

# %%
#factcheckgreek+greekhoaxes+cyprus+postgres+fullfacts
df = pd.concat([train1,train2,train3,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.764
#
# Model Recall: 0.764
#
# Model Precision: 0.765
#
# Model F1-Score: 0.765
#
# Cross validation score: [0.794 0.789 0.737 0.743 0.718 0.793 0.764 0.799 0.77  0.759]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       300
#            1       0.84      0.83      0.84        90
#            2       0.17      0.17      0.17        46
#
#     accuracy                           0.76       436
#    macro avg       0.62      0.61      0.61       436
# weighted avg       0.77      0.76      0.76       436

# %%
#factcheckgreek+greekhoaxes+cyprus+postgres+fullfacts+snopes
df = pd.concat([train1,train2,train3,train4,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.743
#
# Model Recall: 0.743
#
# Model Precision: 0.744
#
# Model F1-Score: 0.743
#
# Cross validation score: [0.686 0.685 0.719 0.732 0.677 0.651 0.689 0.719 0.74  0.694]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       405
#            1       0.68      0.65      0.66       141
#            2       0.25      0.26      0.26        42
#
#     accuracy                           0.74       588
#    macro avg       0.58      0.58      0.58       588
# weighted avg       0.74      0.74      0.74       588

# %%
#factcheckgreek+greekhoaxes+cyprus+postgres+fullfacts+snopes+reuters
df = pd.concat([train1,train2,train3,train4,train5,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.741
#
# Model Recall: 0.741
#
# Model Precision: 0.741
#
# Model F1-Score: 0.741
#
# Cross validation score: [0.763 0.752 0.756 0.777 0.792 0.683 0.717 0.728 0.77  0.702]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       398
#            1       0.76      0.77      0.76       213
#            2       0.26      0.26      0.26        53
#
#     accuracy                           0.74       664
#    macro avg       0.61      0.61      0.61       664
# weighted avg       0.74      0.74      0.74       664

# %%
# greekhoaxes+factcheckgreek+cyprus+fullfacts+postgres
df = pd.concat([train1,train2,train3,train6])
df = df[df.label<=2]
df.reset_index(drop=True, inplace=True)
arr = [df.iloc[i,2] for i in range(len(df))]
X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,3]).astype('int'), test_size=0.2, random_state=42)
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.764
#
# Model Recall: 0.764
#
# Model Precision: 0.765
#
# Model F1-Score: 0.765
#
# Cross validation score: [0.794 0.789 0.737 0.743 0.718 0.793 0.764 0.799 0.77  0.759]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       300
#            1       0.84      0.83      0.84        90
#            2       0.17      0.17      0.17        46
#
#     accuracy                           0.76       436
#    macro avg       0.62      0.61      0.61       436
# weighted avg       0.77      0.76      0.76       436
