# %%
import sys
sys.path.append('../scripts')  
from models import *
from df_handling import * 
from text_embedding import *
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/politifacts_emb.csv')
df = unravel_df(df, ['text_embedding'])

# %%
df.verdict.value_counts()
# Out:
# 0    5625
# 2    3597
# 4    3432
# 3    3332
# 5    2703
# 1    2463
# Name: verdict, dtype: int64

# %%
df2 = pd.read_json('../data/politifact_factcheck_data.json', lines=True)
df2.verdict.value_counts()
# Out:
# false           5625
# half-true       3597
# mostly-false    3432
# mostly-true     3332
# pants-fire      2703
# true            2463
# Name: verdict, dtype: int64

# %%
mapping = {4:0, 3:1, 5:0, 2:2, 0:0, 1:1}
df['verdict'] = df['verdict'].map(mapping)
df['verdict'].value_counts()
# Out:
# 0    11760
# 1     5795
# 2     3597
# Name: verdict, dtype: int64

# %%
arr = [df.iloc[i,2] for i in range(len(df))]


X_train, X_test, y_train, y_test= train_test_split(arr  , np.array(df.iloc[:,0]).astype('int'), test_size=0.2, random_state=42)

# %%
NaiveBayes(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.532
#
# Model Recall: 0.532
#
# Model Precision: 0.571
#
# Model F1-Score: 0.547
#
# Cross validation score: [0.543 0.564 0.557 0.547 0.571 0.533 0.535 0.527 0.541 0.535]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.61      0.67      2352
#            1       0.45      0.49      0.47      1164
#            2       0.24      0.34      0.28       715
#
#     accuracy                           0.53      4231
#    macro avg       0.47      0.48      0.47      4231
# weighted avg       0.57      0.53      0.55      4231

# %%
LogisticReg(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.61
#
# Model Recall: 0.61
#
# Model Precision: 0.562
#
# Model F1-Score: 0.557
#
# Cross validation score: [0.614 0.629 0.612 0.631 0.608 0.616 0.618 0.6   0.613 0.614]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.85      0.74      2352
#            1       0.50      0.49      0.49      1164
#            2       0.35      0.03      0.06       715
#
#     accuracy                           0.61      4231
#    macro avg       0.50      0.45      0.43      4231
# weighted avg       0.56      0.61      0.56      4231

# %%
SVM(X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 SVM(X_train, X_test, y_train, y_test)
#
# File c:\Users\johnk\Desktop\LLM\classifications\../scripts\models.py:149, in SVM(X_train, X_test, y_train, y_test)
#     147 confusion_matrix = metrics.confusion_matrix(np.array(y_test), y_pred )
#     148 classification = metrics.classification_report(np.array(y_test), y_pred )
# --> 149 scores = cross_val_score(svm_classifier, X_train,np.array(y_train), cv=10)
#     151 precision = metrics.precision_score(y_test, y_pred, average='weighted')
#     152 recall = metrics.recall_score(y_test, y_pred, average='weighted')
#
# File c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:562, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
# ...

# %%
KNeigh(X_train, X_test, y_train, y_test)
# Out:
#   File "c:\Users\johnk\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Model Accuracy: 0.589
#
# Model Recall: 0.589
#
# Model Precision: 0.552
#
# Model F1-Score: 0.561
#
# Cross validation score: [0.588 0.608 0.577 0.58  0.593 0.577 0.587 0.574 0.581 0.572]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.79      0.72      2352
#            1       0.47      0.46      0.47      1164
#            2       0.31      0.12      0.18       715
#
#     accuracy                           0.59      4231
#    macro avg       0.48      0.46      0.46      4231
# weighted avg       0.55      0.59      0.56      4231

# %%
DecisionTree(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.476
#
# Model Recall: 0.476
#
# Model Precision: 0.482
#
# Model F1-Score: 0.479
#
# Cross validation score: [0.475 0.472 0.473 0.474 0.478 0.483 0.489 0.478 0.48  0.478]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      2352
#            1       0.35      0.35      0.35      1164
#            2       0.22      0.24      0.23       715
#
#     accuracy                           0.48      4231
#    macro avg       0.40      0.40      0.40      4231
# weighted avg       0.48      0.48      0.48      4231

# %%
RandomForest(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.593
#
# Model Recall: 0.593
#
# Model Precision: 0.591
#
# Model F1-Score: 0.509
#
# Cross validation score: [0.6   0.596 0.585 0.602 0.601 0.585 0.594 0.595 0.599 0.598]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.93      0.73      2352
#            1       0.51      0.28      0.36      1164
#            2       0.67      0.01      0.01       715
#
#     accuracy                           0.59      4231
#    macro avg       0.60      0.40      0.37      4231
# weighted avg       0.59      0.59      0.51      4231

# %%
MLP(X_train, X_test, y_train, y_test)
# Out:
# Model Accuracy: 0.547
#
# Model Recall: 0.547
#
# Model Precision: 0.541
#
# Model F1-Score: 0.544
#
# Cross validation score: [0.572 0.559 0.568 0.566 0.556 0.541 0.556 0.572 0.551 0.55 ]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.71      0.70      2352
#            1       0.45      0.43      0.44      1164
#            2       0.21      0.20      0.21       715
#
#     accuracy                           0.55      4231
#    macro avg       0.45      0.45      0.45      4231
# weighted avg       0.54      0.55      0.54      4231
